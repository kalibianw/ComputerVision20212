# %% [markdown]
# ## Mophological Transformations

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

if os.path.exists("../resource/img/j.png"):
    print("True")
else:
    print("False")
img = cv2.imread("../resource/img/j.png", 0)
kernel = np.ones((5, 5), np.uint8)
# kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
# kernel = cv2.getStructuringElement(cv2.MORPH_ELIPSE, (5, 5))
# kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (5, 5))
# Out:
# True

# %% [markdown]
# ### Erosion

# %%
erosion = cv2.erode(img, kernel, iterations=1)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(erosion)
plt.title("Eerosion")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Dilation

# %%
dilation = cv2.dilate(img, kernel, iterations=1)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(dilation)
plt.title("Dilation")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Opening

# %%
img = cv2.imread("../resource/img/opening.png")
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(opening)
plt.title("Opening")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Closing

# %%
img = cv2.imread("../resource/img/closing.png")
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(closing)
plt.title("Closing")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Morphological Gradient

# %%
img = cv2.imread("../resource/img/j.png")
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(gradient)
plt.title("Morphological Gradient")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Top Hat

# %%
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(tophat)
plt.title("Top Hat")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Black Hat

# %%
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(blackhat)
plt.title("Black Hat")
plt.xticks([])
plt.yticks([])

plt.show()
