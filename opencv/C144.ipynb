# %% [markdown]
# ## Smoothing Images

# %% [markdown]
# ### 2D Convolution(Image Filtering)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("../resource/img/OpenCV logo.png")
img = cv2.resize(img, (243, 300))

# %%
n = 15

kernel = np.ones((n, n), np.float32) / 25
dst = cv2.filter2D(img, -1, kernel)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(dst)
plt.title("Averaging")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ## Image Blurring(Image Smoothing)

# %% [markdown]
# ### Averaging

# %%
blur = cv2.blur(img, (5, 5))

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(blur)
plt.title("Blurred")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Gaussian Filtering

# %%
blur = cv2.GaussianBlur(img, (5, 5), 0)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(blur)
plt.title("Gaussian Blurred")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Median Filtering

# %%
img = cv2.imread("../resource/img/noisy image.png")
blur = cv2.medianBlur(img, 15)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(blur)
plt.title("Median Blurred")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Bilateral Filtering

# %%
img = cv2.imread("../resource/img/check stripe image.jpg")

blur = cv2.bilateralFilter(img, 9, 75, 75)

plt.subplot(121)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(122)
plt.imshow(blur)
plt.title("Bilateral Blurred")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### Comparison all of above

# %%
img = cv2.imread("../resource/img/noisy image.png")
img = cv2.resize(img, (300, 301))

# 2D Convolution
kernel = np.ones((5, 5), np.float32) / 25
dst = cv2.filter2D(img, -1, kernel)

# Averaging
average_blurred = cv2.blur(img, (5, 5))

# Gaussian
gaussian_blurred = cv2.GaussianBlur(img, (5, 5), 0)

# Median
median_blurred = cv2.medianBlur(img, 5)

# Bilateral
bilateral_blurred = cv2.bilateralFilter(img, 9, 75, 75)

plt.subplot(231)
plt.imshow(img)
plt.title("Original")
plt.xticks([])
plt.yticks([])

plt.subplot(232)
plt.imshow(dst)
plt.title("2D Convolution")
plt.xticks([])
plt.yticks([])

plt.subplot(233)
plt.imshow(average_blurred)
plt.title("Averaging")
plt.xticks([])
plt.yticks([])

plt.subplot(234)
plt.imshow(gaussian_blurred)
plt.title("Gaussian")
plt.xticks([])
plt.yticks([])

plt.subplot(235)
plt.imshow(median_blurred)
plt.title("Median")
plt.xticks([])
plt.yticks([])

plt.subplot(236)
plt.imshow(bilateral_blurred)
plt.title("Bilateral")
plt.xticks([])
plt.yticks([])

plt.show()
